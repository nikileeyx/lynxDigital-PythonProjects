# %% [markdown]
# # **Python Turtle Programming**
# “Turtle” is a python feature like a drawing board, which lets you command a turtle to draw all over it! You can use functions like turtle. forward(...) and turtle. ... function tells the turtle to move forward by the given distance.

# %% [markdown]
# ## **1. Setting Up**
#
# First, let us import the necessary packages for this module!

# %%
# !pip3 install ColabTurtle
# Out:
# ...
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-cp37-none-any.whl size=7659 sha256=fc2e878c4dc676b590bc66a0114f51f34a5270491afde03305ec29db50c9484e
#   Stored in directory: /root/.cache/pip/wheels/df/e9/3f/df3fccd8971c5473dc0c6450984cd057de8c9a1271069ebf18
# Successfully built ColabTurtle
# ...

# %%
from ColabTurtle.Turtle import *

# %% [markdown]
# ## **2. Exploring Turtle Programming**
#
# First, let us make the Turtle appear on the screen!
# https://trinket.io/challenges/holiday-tree.html

# %%
initializeTurtle()
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#
#         <g visibility=visible transform="rotate(360,400,250) translate(382, 232)">
# ...

# %% [markdown]
# Good job! Now let is make the Turtle navigate.
#
# **Writing Letters**
# We can use the commands to draw shapes and letters on the canvas! We can use the following command to set the colour of the Turtle's trace
#
# ```
# forward(units) | fd(units) -> Moves the turtle in the direction it is facing, by units pixels
#
# ```
#
# Now you try!

# %%
forward(#include number here)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="220.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,400.0,220.0) translate(382.0, 202.0)">
# ...

# %%
backward(#include number here)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="220.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="220.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,400.0,250.0) translate(382.0, 232.0)">
# ...

# %% [markdown]
# **Now you try!**

# %%
left(#include number here)
backward(#include number here)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="220.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="220.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="250.0" x2="410.261" y2="278.191" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(340,410.261,278.191) translate(392.261, 260.191)">
# ...

# %% [markdown]
# **Draw A Circle and Polygon**

# %%
#Drawing Shapes
#Write your code here

times = 4
counter = 0
for counter in range(times):
  left(20)
  backward(30)
  counter += 1
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %% [markdown]
# **Writing Letters**
# We can use the commands to draw shapes and letters on the canvas! We can use the following command to set the colour of the Turtle's trace
#
# ```
# color("[color]")
# ```
#
# You can use the "goto" command to change the location of your Turtle.
# ```
# goto(x-coordinate, y-coordinate)
# ```
#
# Try using different colours to draw the letter "H" and "O".

# %%
#Drawing Shapes
#Write your code here
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %% [markdown]
# Practice 1: Use the goto(x,y) command to move the turtle to (-20, -175)

# %% [markdown]
# ## **3. Drawing Shapes with Loops**
# We can use the loops such as "for" and "if" loops to draw images with less code!

# %%
initializeTurtle()

counter = 

for counter in range():
  left()
  forward()
  counter+=
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %% [markdown]
# **Drawing a shape with different colours!**
#
# Now you can try to draw the same shape but with the same turtle in different colours! For a hint, the colours are strings!
#
# ```
# # Start each cell with "initialiseTurtle()"
# ```
#
# Now you try!

# %%
initializeTurtle()
counter = 0
counterCol = 0
colour = []

for counter in range(4):
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="300.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="300.0" y1="250.0" x2="300.0" y2="350.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="300.0" y1="350.0" x2="400.0" y2="350.0" stroke-linecap="round" style="stroke:green;stroke-width:4"/><line x1="400.0" y1="350.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:red;stroke-width:4"/><line x1="400.0" y1="250.0" x2="300.0" y2="250.0" stroke-linecap="round" style="stroke:yellow;stroke-width:4"/>
#         <g visibility=visible transform="rotate(270,300.0,250.0) translate(282.0, 232.0)">
# ...

# %% [markdown]
# ## **4. The Python Turtle Draw A Smiley!**
#
# Draw a smiley face in this box below!

# %%
#Use the goto(x,y) command to move the turtle to (-20, -175)

# %%
# Your code here!

initializeTurtle()
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="210.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="320" y1="250" x2="320.0" y2="210.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="310" y1="300" x2="325.0" y2="325.981" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="325.0" y1="325.981" x2="350.981" y2="340.981" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="350.981" y1="340.981" x2="380.981" y2="340.981" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="380.981" y1="340.981" x2="406.962" y2="325.981" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="406.962" y1="325.981" x2="421.962" y2="300.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#         <g visibility=visible transform="rotate(390,421.962,300.0) translate(403.962, 282.0)">
# ...

# %% [markdown]
# ## **5. The Python Turtle Final Challenge!**
#
# Having done the above challenges, ink your mark here at the end by writing your name using Turtle!

# %%
## **5. The Python Turtle Final Challenge!**

Having done the above challenges, ink your mark here at the end by writing your name using Turtle!
